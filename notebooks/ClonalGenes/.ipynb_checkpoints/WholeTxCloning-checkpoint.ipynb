# %%
import switchy.CloneStatsKlein as cs
import pandas as pd
import numpy as np
import sys
import os
import time
import random
import copy
import math
import scanpy as sc
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib as mpl

import seaborn as sns
import autoreload
params = {
    'font.size': 12,
    'axes.titlesize': 12,
    'axes.labelsize': 12,
    'legend.fontsize': 12,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'font.family': "Helvetica",
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'figure.dpi': 300
   }

mpl.rcParams.update(params)

sns.set_style("ticks")

savefig_args = {"dpi": 300, "bbox_inches": "tight", "pad_inches": 0, "transparent": True}
mpl.rc('savefig', dpi=300)
output_dir = "figures/ClonalGenesCorrelations"
output_suffix = ""
output_formats = [".png", ".pdf"]

def save_figure(fig, name, output_dir=output_dir, output_suffix=output_suffix, output_formats=output_formats, savefig_args=savefig_args):
    for output_format in output_formats:
        fig.savefig(output_dir + "/" + name + output_suffix + output_format, **savefig_args)
    return None

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

out_dir = "processed_data/stats_tests"
#import auto reload
# %load_ext autoreload
# %autoreload 2

CountsFile = '../data/Combined_PC_Labeled.h5ad'
ChangeoFile = '../../../SharedData/ShazamQCedIGH.tab'
datatype = 'log'
# Out:
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
# Want to parse the arguments 
df_tests, adata_obs, df = cs.main()
# Out:
# Running Stats on Variance Within Clones!
# removing variable immune receptor genes which may drive clustering
# Trying to set attribute `.obs` of view, copying.
# (1436, 67) shape of adata_obs
# Running Real Permutation Test with CLONE and 1000 Shuffles
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_tests.sort_values('corrected_pvalue')
# Out:
# --------------------------------------------------------------------
# NameError                          Traceback (most recent call last)
# <ipython-input-3-97a753c87a81> in <module>
# ----> 1 df_tests.sort_values('corrected_pvalue')
#
# NameError: name 'df_tests' is not defined

# %%
df_sorted2 = df_tests.sort_values('corrected_pvalue')

# %%
x = np.log10(df_sorted2.pvalue.to_list())

# %%
sns.distplot(x)

# %%
adata = sc.read_h5ad('../data/Combined_PC_Labeled.h5ad')

np.seterr(all = 'warn')
sc.pp.calculate_qc_metrics(adata, inplace = True)

common_genes = adata.var[adata.var['n_cells_by_counts'] > 400]
# Out:
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/scanpy/preprocessing/_qc.py:386: RuntimeWarning: invalid value encountered in true_divide
#   return values / sums[:, None]

# %%
df_sorted2[df_sorted2['gene'].isin(common_genes.index)]
# Out:
#       score      gene       pvalue corrected_pvalue
# 4776      0  HLA-DQB2  9.30794e-34      1.36008e-29
# 3614      0     H2AFZ  1.59691e-30       2.3334e-26
# 8938      0     GAPDH  2.26662e-30      3.31198e-26
# 2195      0   ATP5MC3  2.71119e-30      3.96159e-26
# 8955      0      TPI1  4.38625e-30      6.40919e-26
# ...     ...       ...          ...              ...
# 5506  0.015   SEPT7P2    0.0189439                1
# 5508  0.255      TNS3     0.251828                1
# 5509  0.017      HUS1    0.0159598                1
# 5512  0.001      UPP1   0.00587739                1
# 5515   0.23    FIGNL1     0.232407                1
#
# [9112 rows x 4 columns]

# %%
changeoAdataObs, df = cs.prepareData(CountsFile=CountsFile, 
                                     ChangeoFile=ChangeoFile, 
                                     datatype='log', 
                                     highly_variable=False, 
                                     n_highly_variable=2000)
# Out:
# removing variable immune receptor genes which may drive clustering
# Trying to set attribute `.obs` of view, copying.
# (1436, 67) shape of adata_obs

# %%
cs.plotWaterfall(df, changeoAdataObs, 'IGHG3', 'CLONE')
# Out:
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# ---------------------------------------------------------------------------
# ...

# %%
cs.plotTestHist(df, changeoAdataObs, 10000, 'ENSG00000277048', 'CLONE')

# %%
sns.scatterplot(df_sorted2['score'], df_sorted2['pvalue'])

# %%
genelist = df_sorted2['gene'].to_list()

# %%
genelist[8]
# Out:
# 'TSC22D3'

# %%
cs.plotTestHist(df, changeoAdataObs, 1000, genelist[1], 'CLONE')
# Out:
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
cs.plotTestHist(df, changeoAdataObs, 1000, genelist[2], 'Exp_Labels')
# Out:
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
cs.plotWaterfall(df, changeoAdataObs, 'GAPDH', 'Exp_Labels')
cs.plotWaterfall(df, changeoAdataObs, 'GAPDH', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'TSC22D3', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'JCHAIN', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'JUN', 'CLONE')
# Out:
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/mswift/local/anaconda3/envs/singlecell/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
cs.plotWaterfall(df, changeoAdataObs, 'BIRC6', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'IGKC', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'IGLC3', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'ANXA4', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'IGHA2', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'AFF3', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'IGHM', 'CLONE')

# %%
cs.plotWaterfall(df, changeoAdataObs, 'ACTBP2', 'CLONE')

# %%
CountsFile = '../data/Combined_PC_Changeo.h5ad'
ChangeoFile = '../../../SharedData/ShazamQCedIGH.tab'
datatype = 'log'

adata, df = cs.prepareData(CountsFile,datatype=datatype, highly_variable=True, n_highly_variable=4000, onlyClones = True, remove_immune_receptors=False)
# Out:
# Trying to set attribute `.obs` of view, copying.
# (885, 68) (18386, 2) shape of adata after filtering

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 885 × 3999
# ...

# %%
df
# Out:
#                     FAM41C  CFAP74  SKI     PANK4  TNFRSF25  Z98884.2    VPS13D  ALPL  RF00019-8  PTAFR  AL356320.1     CSF3R  EXO5  C1orf228  CCDC17  AL049637.1  SLC25A6P3  TTC22       JUN      PATJ     SYDE2    TMEM56       DBT      VAV3  AL360270.2  CHI3L2  OVGP1   SLC16A1    NOTCH2  AC241952.1  AC239868.1     RPRD2      CTSK    ZNF687     ASH1L     FCRL3     FCRL2   RPSAP18  CD244  SH2D1B  GPR161  TBX19     BLZF1  KLHL20     LAMC1     EDEM3  IVNS1ABP     GPR25      IPO9  AC098934.1  PPP1R15B  LRRN2     DSTYK    RASSF5       CR2    LPGAT1  C1orf115    HHIPL2   FAM177B  ENAH  LINC01703  OBSCN-AS1  AL732292.2      LYST    HEATR1  CHML  ZNF669     OR2W3  MYT1L     LPIN1  AC104623.2  LINC00954     WDR35      PUM2  PTGES3P2  CLIP4  CAPN14  AL133245.1     BIRC6  RNU6-577P  CYP1B1  DHX57  LINC01126  BCYRN1  ACTG1P22  AC007381.1     EHBP1  WDPCP    SLC1A4     CEP68    PPP3R1     TTC31  HK2  AC093162.2      GNLY     PTCD3     KDM3A  CD8A  LINC01943  SMYD1      IGKC  IGKV3-11   IGKV4-1  \
# ...

# %%
tests = pd.read_csv('../notebooks/processed_data/stats_tests/CLONE_tests_True_3000_10000_log', index_col=0)

# %%
tests.sort_values('corrected_pvalue')
# Out:
#        score             gene        pvalue  corrected_pvalue
# 2913  0.0000            IGLC2  2.043666e-20      5.474982e-17
# 352   0.0000             IGKC  5.755745e-19      1.541964e-15
# 2207  0.0000         IGHV3-30  1.708526e-17      4.577141e-14
# 2903  0.0000         IGLV3-21  3.737402e-17      1.001250e-13
# 363   0.0000         IGKV3-20  4.242465e-17      1.136556e-13
# ...      ...              ...           ...               ...
# 1030  0.5406             TPBG  5.626810e-01      1.000000e+00
# 1031  0.4206            UBE3D  4.345751e-01      1.000000e+00
# 1032  0.2051           DOPEY1  2.087233e-01      1.000000e+00
# 1034  0.0367           CYB5R4  3.322781e-02      1.000000e+00
# 2997  0.0286  Cytomegalovirus  1.674440e-02      1.000000e+00
#
# [2679 rows x 4 columns]

# %%
merged = pd.merge(adata.var, tests, left_index=True, right_on='gene')

# %%
merged.head()
# Out:
#    n_cells  n_counts  highly_variable     means  dispersions  dispersions_norm   score     gene    pvalue  corrected_pvalue
# 0      314   62661.0             True  4.273932     7.368819          0.930959  0.3190    ISG15  0.323622               1.0
# 3       49    8910.0             True  2.404039     7.891996          1.857640  0.4837      SKI  0.509263               1.0
# 4        7     575.0             True  0.500604     6.179563          1.227775  0.9770    MEGF6  0.735544               1.0
# 8      116   11252.0             True  2.618426     7.422123          1.305523  0.3610   KLHL21  0.372495               1.0
# 9      200   20138.0             True  3.167785     7.302662          1.082711  0.7897  DNAJC11  0.795662               1.0

# %%
plt.scatter(x=np.log10(merged['n_cells']), y = np.log10(merged['corrected_pvalue'].astype('float')), s=2, alpha = 0.4)
plt.xlabel('Number of Cells Expressing Gene Z (log10)')
plt.ylabel("Bonferroni Corrected P-Value (log10)")
# Out:
# Text(0, 0.5, 'Bonferroni Corrected P-Value (log10)')

# %%
merged['log_corrected_pvalue'] = np.log10(merged['corrected_pvalue'].astype('float'))

# %%
merged['log_n_counts'] = np.log10(merged['n_counts'])

# %%
bins = np.linspace(-19, 0, 60)
plt.hist(merged['log_corrected_pvalue'], bins = bins, histtype='step')
plt.yscale('log')
#plt.xscale('log')
plt.xlabel('Bonferroni Corrected P-value (log10)')
plt.ylabel("Occurrences")
# Out:
# Text(0, 0.5, 'Occurrences')

# %%
sns.pairplot(merged[['n_cells', 'log_n_counts', 'means', 'log_corrected_pvalue', 'dispersions']])
