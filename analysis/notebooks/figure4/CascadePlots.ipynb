# %%
import pandas as pd
import numpy as np
import scanpy as sc
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pathlib
import scirpy as ir
import pathlib
from matplotlib.lines import Line2D
savefig_args = {"dpi": 600, "bbox_inches": "tight", "pad_inches": 0, "transparent": True}
output_dir='../../figures/figure4'
pathlib.Path(output_dir).mkdir(parents=True, exist_ok=True)
output_suffix = ""
output_formats = [".eps"]
from statsmodels.stats.multitest import multipletests
def correct_p(df, column, method):
    result = multipletests(df[column], method = method)
    df['significant'] = result[0]
    df[column + 'corrected_pvalue'] = result[1]
    return df
plt.style.use('seaborn-paper')
plt.style.use('seaborn-whitegrid')
plt.style.use('../../scripts/paper.mplstyle')
width = plt.rcParams['figure.figsize'][0]
height = plt.rcParams['figure.figsize'][1]
plt.rcParams['legend.markerscale'] = 0.5
def save_figure(fig, name, output_dir=output_dir, output_suffix=output_suffix, output_formats=output_formats, savefig_args=savefig_args):
    for output_format in output_formats:
        fig.savefig(output_dir + "/" + name + output_suffix + output_format, format='eps', **savefig_args)
    return None

# %run ../../scripts/plotting_helper.py

# %%
h5ad = '../../processed_data/h5ad_objects/bcells.h5ad'
adata = sc.read_h5ad(h5ad)

# %% [markdown]
# # In Vivo Sample

# %%
label = 'clone_id'
hue = 'bcelltype'
palette = bcelltype_colors
clone_size = 2
gene = 'IGKC'
sub_adata = adata[~adata.obs.sample_id.str.contains('Day')]
fig = plot_dual_cascade(sub_adata[sub_adata.obs.IR_VJ_1_c_call == 'IGKC'], label, hue, palette, clone_size, gene, width, height)
# Out:
# /home/michaelswift/miniconda3/envs/muon/lib/python3.9/site-packages/pandas/core/indexing.py:1625: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   self.obj[key] = value
# Shuffled: False
#  average CV: 0.05
# /home/michaelswift/miniconda3/envs/muon/lib/python3.9/site-packages/pandas/core/indexing.py:1625: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   self.obj[key] = value
# Shuffled: True
#  average CV: 0.1

# %%
save_figure(fig, "IGKC_cascade_invivo")

# %% [markdown]
# # In Vitro Samples

# %%
label = 'clone_id'
hue = 'bcelltype'
palette = bcelltype_colors
clone_size = 3
gene = 'IGKC'
sub_adata = adata[adata.obs.sample_id.str.contains('Day')]
sub_adata = sub_adata[~sub_adata.obs.sample_id.str.contains('Day 0')]

fig = plot_dual_cascade(sub_adata, label, hue, palette, clone_size, gene, width, height)
# Out:
# /home/michaelswift/miniconda3/envs/muon/lib/python3.9/site-packages/pandas/core/indexing.py:1625: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   self.obj[key] = value
# Shuffled: False
#  average CV: 0.67
# /home/michaelswift/miniconda3/envs/muon/lib/python3.9/site-packages/pandas/core/indexing.py:1625: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   self.obj[key] = value
# Shuffled: True
#  average CV: 0.92

# %%
save_figure(fig, "IGKC_cascade_amongst_IGKC")

# %%
label = 'clone_id'
hue = 'bcelltype'
palette = bcelltype_colors
clone_size = 3
gene = 'IGKC'
sub_adata = adata[adata.obs.sample_id.str.contains('Day')]
fig = plot_dual_cascade(sub_adata, label, hue, palette, clone_size, gene, width, height)
# Out:
# /home/michaelswift/miniconda3/envs/muon/lib/python3.9/site-packages/pandas/core/indexing.py:1625: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   self.obj[key] = value
# Shuffled: False
#  average CV: 0.68
# /home/michaelswift/miniconda3/envs/muon/lib/python3.9/site-packages/pandas/core/indexing.py:1625: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   self.obj[key] = value
# Shuffled: True
#  average CV: 0.91

# %%
save_figure(fig, "IGKC_cascade_amongst_all")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
label = 'clone_id'
hue = 'isotype_simple'
palette = igh_colors_simple
clone_size = 3
gene = 'IGHE'
fig = plot_dual_cascade(adata[adata.obs.sample_id.str.contains("Day")], label, hue, palette, clone_size, gene, width, height)
# Out:
# /home/michaelswift/miniconda3/envs/muon/lib/python3.9/site-packages/pandas/core/indexing.py:1625: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   self.obj[key] = value
# Shuffled: False
#  average CV: 0.82
# /home/michaelswift/miniconda3/envs/muon/lib/python3.9/site-packages/pandas/core/indexing.py:1625: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   self.obj[key] = value
# Shuffled: True
#  average CV: 0.86

# %%
save_figure(fig, "IGHE_cascade_amongst_all")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
